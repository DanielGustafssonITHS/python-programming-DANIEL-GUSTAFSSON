# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Vet inte om en funktion är nödvändig här men men...

filename = "unlabelled_data.csv"

def unlabelled_data(filedata):
    data = np.loadtxt(filedata, delimiter=",")
    return data

data = unlabelled_data(filename)

# %%
x = data[:, 0]
y = data[:, 1]
x2 = (-5, 4)
y2 = (5, -4)
plt.scatter(x, y)
plt.scatter(x, y)
plt.plot(x2, y2)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Oklassificierade punkter")
plt.grid()
plt.show()

# y = -1x + 0

# %%
#

# Ladda in filen

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd



k = -1
m = 0

# definera en funktion som baseras på y = kx + m
def f_line(x):
    return -0.489 * x

def g_line(x):
    return -2 * x + 0.16

def h_line(x):
    return 800 * x - 120   

def classify_datapoints(x, y, k, m):
    line_y = k * x + m
    if y >= line_y:
        return 1
    else:
        return 0


def plot_classify(data, k, m):
    colors = data["label"].map({0: "red", 1:"blue"})
    plt.scatter(data["x"], data["y"], c = colors)

    x_vals = sorted(data["x"])
    y_vals = [k * x + m for x in x_vals]
    plt.plot(x_vals, y_vals, color = "black", label = f"y = {k}x + {m}")

    plt.plot(x_vals, [f_line(x) for x in x_vals], color = "green", label = f"f(x) = -0.489x")
    plt.plot(x_vals, [g_line(x) for x in x_vals], color = "yellow", label = f"g(x) = -2 + 0.16")
    plt.plot(x_vals, [h_line(x) for x in x_vals], color = "purple", label = f"h(x) = 800x - 120")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("Klassifiering efter linje")
    plt.xlim(-25, 25)
    plt.ylim(-25, 25)
    plt.legend(loc = 'upper left')
    plt.show()



if __name__=="__main__":

    filename = "unlabelled_data.csv"

    data = pd.read_csv(filename)

    data.columns = ["x", "y"]
    data["label"] = data.apply(lambda row: classify_datapoints(row["x"], row["y"], k, m), axis=1)

    data.to_csv("labelled_data.csv",index=False)

    plot_classify(data, k, m)


"""
    colors = data["label"].map({0: "red", 1: "blue"})
    plt.scatter(data["x"], data["y"], c=colors, label="Punkter")


    x_vals = sorted(data["x"])
    y_vals = [k * x + m for x in x_vals]
    plt.plot(x_vals, y_vals, color="black", label=f"y = {k}x + {m}")

    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("Klassificering med linje")
    plt.legend()
    plt.show()

"""
# Out:
# '\n    colors = data["label"].map({0: "red", 1: "blue"})\n    plt.scatter(data["x"], data["y"], c=colors, label="Punkter")\n\n\n    x_vals = sorted(data["x"])\n    y_vals = [k * x + m for x in x_vals]\n    plt.plot(x_vals, y_vals, color="black", label=f"y = {k}x + {m}")\n\n    plt.xlabel("x")\n    plt.ylabel("y")\n    plt.title("Klassificering med linje")\n    plt.legend()\n    plt.show()\n\n'
